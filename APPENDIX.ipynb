# %%
# Required Inputs for All Exercises
SEED_NUM = 6  # Replace with the last digit of your student number
STUDENT_MAJOR = "BSECE"  # e.g., BSECE, BSME
FAVORITE_ARTIST = "Jan Roberts" 
LOCAL_HAZARD = "FIRE" 

# Numeric logic from the manual
CONTROL_NUM = max(3, SEED_NUM)
