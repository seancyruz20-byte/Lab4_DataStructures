# %%
# Required Inputs for All Exercises
SEED_NUM = 6  # Replace with the last digit of your student number
STUDENT_MAJOR = "BSECE"  # e.g., BSECE, BSME
FAVORITE_ARTIST = "Jan Roberts" 
LOCAL_HAZARD = "Fire" 

# Numeric logic from the manual
CONTROL_NUM = max(3, SEED_NUM)

# %%
from collections import defaultdict, Counter

# Initial Stream
stream = [
    ("TUP Manila", "BSECE"),
    ("TUP Taguig", f"BSME_v{CONTROL_NUM}"),
    ("TUP Manila", f"BSME_v{CONTROL_NUM}"), 
    ("TUP Visayas", STUDENT_MAJOR),
    ("TUP Taguig", "BSECE"), 
    ("TUP Manila", "BSECE")
]

# Data Expansion: Adding exactly (CONTROL_NUM + 3) custom tuples
for i in range(CONTROL_NUM + 3):
    stream.append(("TUP Manila", STUDENT_MAJOR))

# Algorithm Phase 1: Aggregation
campus_map = defaultdict(list)
for campus, program in stream:
    campus_map[campus].append(program)

# Algorithm Phase 2: Frequency Analysis (Focusing on Manila)
manila_counter = Counter(campus_map["TUP Manila"])
top_program, frequency = manila_counter.most_common(1)[0]

# Outputs for Assessment Table
print(f"CONTROL_NUM Used: {CONTROL_NUM}")
print(f"Expanded Stream Length: {len(stream)}")
print(f"Total Applications Processed for TUP Manila: {len(campus_map['TUP Manila'])}")
print(f"Top Requested Program at TUP Manila: {top_program}")
print(f"Exact Frequency of Top Program: {frequency}")
# Out:
# CONTROL_NUM Used: 6
# Expanded Stream Length: 15
# Total Applications Processed for TUP Manila: 12
# Top Requested Program at TUP Manila: BSECE
# Exact Frequency of Top Program: 11

# %%
# Initialize Sets
festival = {"Ben&Ben", "SB19", "Bini", "Eraserheads", "FAVORITE_ARTIST", "Zild", f"Indie Artist {CONTROL_NUM}"}
user_a = {"Ben&Ben", "Bini", "Maki", "Dionela", FAVORITE_ARTIST}
user_b = {"SB19", "Eraserheads", "Zild", f"Indie Artist {CONTROL_NUM}", "Parokya ni Edgar"}

# Data Expansion: Update user_a with exactly CONTROL_NUM new artists
for i in range(CONTROL_NUM):
    user_a.add(f"New Artist {i}")

# Jaccard Calculation Function
def calculate_jaccard(set1, set2):
    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))
    return (intersection / union) * 100

# Calculate Similarities
sim_a = calculate_jaccard(user_a, festival)
sim_b = calculate_jaccard(user_b, festival)

# Find Dealbreakers (Artists User A listens to that are NOT in the festival)
dealbreakers = user_a.difference(festival)

# Outputs for Assessment Table
print(f"Total Artists in Expanded Festival: {len(festival)}")
print(f"Length of Intersection (User A & Festival): {len(user_a.intersection(festival))}")
print(f"Length of Union (User A & Festival): {len(user_a.union(festival))}")
print(f"User A Jaccard Similarity: {sim_a:.2f}%")
print(f"User B Jaccard Similarity: {sim_b:.2f}%")
print(f"User A Dealbreaker Artists: {dealbreakers}")
# Out:
# Total Artists in Expanded Festival: 7
# Length of Intersection (User A & Festival): 2
# Length of Union (User A & Festival): 16
# User A Jaccard Similarity: 12.50%
# User B Jaccard Similarity: 50.00%
# User A Dealbreaker Artists: {'New Artist 2', 'Dionela', 'New Artist 5', 'New Artist 0', 'New Artist 4', 'Maki', 'New Artist 3', 'Jan Roberts', 'New Artist 1'}

# %%
from collections import deque, Counter

# Initialize Deque with limit
dq = deque(maxlen=5)
spam_filter = Counter()
stored_alerts = []

# Initial Burst
burst = [
    (CONTROL_NUM, "WEATHER"), (CONTROL_NUM + 1, "TRAFFIC"),
    (CONTROL_NUM + 2, "WEATHER"), (CONTROL_NUM + 3, "WEATHER"),
    (CONTROL_NUM + 4, LOCAL_HAZARD), (CONTROL_NUM + 5, "WEATHER"),
    (CONTROL_NUM + 6, "TRAFFIC")
]

# Data Expansion: Append exactly (CONTROL_NUM + 2) custom alerts
for i in range(CONTROL_NUM + 2):
    burst.append((CONTROL_NUM + 7 + i, "SYSTEM_TEST"))

# Algorithm (The Sliding Window)
for timestamp, category in burst:
    # Spam Rule: If category count >= 2 in current window, reject it
    if spam_filter[category] < 2:
        dq.append((timestamp, category))
        stored_alerts.append((timestamp, category))
        # Update the filter based on the current sliding window (deque)
        spam_filter = Counter(cat for ts, cat in dq)
    else:
        print(f"Alert Rejected (Spam): {category} at {timestamp}")

# Outputs for Assessment Table
print(f"LOCAL_HAZARD Used: {LOCAL_HAZARD}")
print(f"Total Burst Size: {len(burst)}")
print(f"Final Deque Length: {len(dq)}")
print(f"Final Sum of Timestamps in Deque: {sum(ts for ts, cat in dq)}")
print(f"Exact Final Deque Output: {list(dq)}")
# Out:
# Alert Rejected (Spam): WEATHER at 9
# Alert Rejected (Spam): WEATHER at 11
# Alert Rejected (Spam): SYSTEM_TEST at 15
# Alert Rejected (Spam): SYSTEM_TEST at 16
# Alert Rejected (Spam): SYSTEM_TEST at 17
# Alert Rejected (Spam): SYSTEM_TEST at 18
# Alert Rejected (Spam): SYSTEM_TEST at 19
# Alert Rejected (Spam): SYSTEM_TEST at 20
# LOCAL_HAZARD Used: Fire
# Total Burst Size: 15
# Final Deque Length: 5
# Final Sum of Timestamps in Deque: 57
# Exact Final Deque Output: [(8, 'WEATHER'), (10, 'Fire'), (12, 'TRAFFIC'), (13, 'SYSTEM_TEST'), (14, 'SYSTEM_TEST')]
